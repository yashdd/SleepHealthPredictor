# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from getpass import getpass
import os

# 🔐 Enter GitHub token securely
token = getpass("Enter your GitHub token: ")

# Set your GitHub username and repo name
username = "yashdd"
repo_name = "SleepHealthPredictor"

# 🚀 Clone the repo
# !git clone https://{token}@github.com/{username}/{repo_name}.git
# %cd {repo_name}
# Out:
# Enter your GitHub token: ··········
# Cloning into 'SleepHealthPredictor'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/SleepHealthPredictor

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-41df8ce2-160f-4803-901b-a642447c8f2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41df8ce2-160f-4803-901b-a642447c8f2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile("mhealth+dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("mhealth+dataset")

print("✅ Dataset extracted into /SleepHealthPredictor/MHEALTHDATASET")
# Out:
# ✅ Dataset extracted into /SleepHealthPredictor/MHEALTHDATASET

# %%
#Checking the dataset files
# !ls mhealth+dataset/MHEALTHDATASET
# Out:
# mHealth_subject10.log  mHealth_subject4.log  mHealth_subject8.log
# mHealth_subject1.log   mHealth_subject5.log  mHealth_subject9.log
# mHealth_subject2.log   mHealth_subject6.log  README.txt
# mHealth_subject3.log   mHealth_subject7.log

# %%
# !git config --global user.email "yashdeshpande877@gmail.com"
# !git config --global user.name "yashdd"

# !git add data_loading_and_cleaning.ipynb
# !git commit -m "Initial notebook: data loading and understanding MHealth dataset"
# !git push origin main
# Out:
# fatal: pathspec 'data_loading_and_cleaning.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	mhealth+dataset.zip
# 	mhealth+dataset/
#
# nothing added to commit but untracked files present (use "git add" to track)
# Everything up-to-date

# %%
# !find /content/drive -name "*cleaning.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled2.ipynb
# /content/drive/MyDrive/Colab Notebooks/Flight Ticket Price Prediction/FlightTicketPredictionipynb.ipynb
# /content/drive/MyDrive/Colab Notebooks/Customer_conversion_prediction_3_0.ipynb
# /content/drive/MyDrive/Colab Notebooks/Depression_Detection_Using_TwitterData/Data_Collection.ipynb
# /content/drive/MyDrive/Colab Notebooks/DAV_Assignment/EDA_for_Population_Estimate_Data.ipynb
# /content/drive/MyDrive/Colab Notebooks/SleepHealthPrediction/data_loading_and_cleaning.ipynb
# ^C
